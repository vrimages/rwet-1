# %%
import random

# %%
keywords = [
    "madness",
    "mind",
    "perception",
    "thoughts",
    "conceptual",
    "cognitive",
    "psychotic",
    "thinking",
    "illness",
    "medicine",
    "strange",
    "unusual",
    "philosophy",
    "water"
]

# %%
abram_keywords = [
    "Human",
    "World",
    "Time",
    "language",
    "experience",
    "written",
    "Body",
    "Oral",
    "Words",
    "Land",
    "Senses",
    "Visible",
    "Relation",
    "Place",
    "Writing",
    "Stories",
    "Sense",
    "Animals",
    "Spoken",
    "Living",
    "Animate",
    "Directly"
]

text_abram = open("abram_spell.txt").read()
if "?" in text_abram: text_abram = text_abram.replace("?",".")
#if "," in text_abram: text_abram = text_abram.replace(",",".")
#if ";" in text_abram: text_abram = text_abram.replace(";",".")


sentences_abram = text_abram.split(". ")
abram_passages = []
for sentence in sentences_abram:
    word = random.randrange(0, len(abram_keywords))
    if abram_keywords[word] in sentence:
        #print(sentence)
        abram_passages.append(sentence)
        
randChoice = 0
for passage in abram_passages:
    randChoice = random.randrange(0,3)
    if(randChoice == 0):
        print(passage)
        
#words_abram = text_abram.split(" ")
#words = []
#words_dict = {}
#for word in words_abram:   
#    if word not in words:
#        words.append(word)
#    elif word not in words_dict.keys():
#        words_dict[word] = 1
#    else:
#        words_dict[word] += 1
    #if "water" in sentence:
        #print(sentence)
      
    #if "magic" in sentence and "medicine" in sentence:
    #    print(sentence)
#print(words_dict)
#sort_words = sorted(words_dict.items(), key=lambda x: x[1], reverse=True)
#print(sort_words)
#for i in sort_words:
#    print(i[0], i[1])
#print(words_dict.iteritems())
# Out:
# Others may wish to dance
# across parts of Chapter 3, which necessarily contains a few somewhat technical sections regarding
# the bodily nature of language
# Yet in tribal cultures that which we call “magic” takes
# its meaning from the fact that humans, in an indigenous and oral context, experience their own
# consciousness as simply one form of awareness among many others
# Our experience may indeed be a variant of these other modes of
# sensitivity; nevertheless, we cannot, as humans, precisely experience the living sensations of another
# form
# Yet we can never
# suspend the flux of participation itself.
# Synaesthesia—The Fusion of the Senses
# Until now we have spoken of perception in primarily visual terms
# Our own languages are continually nourished by these other voices—by the roar of
# waterfalls and the thrumming of crickets
# The original Semitic aleph-beth, then, established a
# character, or letter, for each of the consonants of the language
# ...

# %%
kusters_keywords = [
    "Time",
    "World",
    "Real",
    "See",
    "Experience",
    "other",
    "Madness",
    "Mad",
    "Rights",
    "Philosophy",
    "Experience",
    "Thinking",
    "People",
    "World",
    "Thoughts",
    "Sense",
    "Madman",
    "Reality",
    "Being",
    "Present",
    "Dream",
    "Realness"
]

text_kusters = open("kusters_mad.txt").read()
if "?" in text_kusters: text_kusters = text_kusters.replace("?",".")
#if "," in text_kusters: text_kusters = text_kusters.replace(",",".")
#if ";" in text_kusters: text_kusters = text_kusters.replace(";",".")

sentences_kusters = text_kusters.split(". ")
kusters_passages = []
for sentence in sentences_kusters:
    word = random.randrange(0, len(kusters_keywords))
    if kusters_keywords[word] in sentence:
        #print(sentence)
        kusters_passages.append(sentence)
        
randChoice = 0
for passage in kusters_passages:
    randChoice = random.randrange(0,3)
    if(randChoice == 0):
        print(passage)


#words_kusters = text_kusters.split(" ")
#words = []
#words_dict = {}
#for word in words_kusters:   
#    if word not in words:
#        words.append(word)
#    elif word not in words_dict.keys():
#        words_dict[word] = 1
#    else:
#        words_dict[word] += 1

#sort_words = sorted(words_dict.items(), key=lambda x: x[1], reverse=True)
#print(sort_words)

#for sentence in sentences_kusters:
    #if "water" in sentence:
        #print(sentence)
#    word = random.randrange(0, len(keywords))
#    if keywords[word] in sentence:
#        print(sentence)
    #if "thoughts and" in sentence:
    #    print(sentence)
    #if "madness" in sentence:
        #print(sentence)
# Out:
# Everything is a wild toss of hallucinations of one kind or another about one
# thing or another
# A Philosophy of Madness : The Experience of Psychotic Thinking, MIT Press, 2020
# This makes the future less certain and less real than the past.
# Seen in this way, the future is no more than a fantasy, a fabrication, and a hope, and it
# belongs to the unreal, the counterfactual.6
# In addition to the abstract but extremely real times of the past and the future, human
# methods for expressing time, such as clocks and calendars, also have a certain reality value.
# Mondays, years, and dates all have real meaning that we take for granted
# A Philosophy of Madness : The Experience of Psychotic Thinking, MIT Press, 2020
# A Philosophy of Madness : The Experience of Psychotic Thinking, MIT Press, 2020
# As one of Stanghellini’s patients (2004, 6) says movingly, “How can this
# world be real, when it is only seen through my brain.”17
# ...

# %%
emezi_keywords = [
    "Inside",
    "Looked",
    "Felt",
    "Time",
    "Against",
    "See",
    "Other",
    "Eyes",
    "Face",
    "Body",
    "Being",
    "Going",
    "Mother",
    "Time",
    "Human",
    "Love",
    "Child",
    "Years",
    "Head",
    "Night",
    "Voice",
    "Flesh"
]


text_emezi = open("emezi_fresh.txt").read()
if "?" in text_emezi: text_emezi = text_emezi.replace("?",".")
#if "," in text_emezi: text_emezi = text_emezi.replace(",",".")
#if ";" in text_emezi: text_emezi = text_emezi.replace(";",".")
#for sentence in sentences_emezi:
#    word = random.randrange(0, len(keywords))
#    if keywords[word] in sentence:
#        print(sentence)

sentences_emezi = text_emezi.split(". ")
emezi_passages = []
for sentence in sentences_emezi:
    word = random.randrange(0, len(emezi_keywords))
    if emezi_keywords[word] in sentence:
        #print(sentence)
        emezi_passages.append(sentence)
        
randChoice = 0
for passage in emezi_passages:
    randChoice = random.randrange(0,1)
    if(randChoice == 0):
        print(passage)

#words_emezi = text_emezi.split(" ")
#words = []
#words_dict = {}
#for word in words_emezi:   
#    if word not in words:
#        words.append(word)
#    elif word not in words_dict.keys():
#        words_dict[word] = 1
#    else:
#        words_dict[word] += 1

#sort_words = sorted(words_dict.items(), key=lambda x: x[1], reverse=True)
#print(sort_words)
# Out:
# Humans find it easier to just lie and
# lie to themselves.
# Ada made him get the condoms anyway, and he told her
# how awkward it had been when the cashier asked him
# what size he needed

# %%
kimmerer_keywords = [
    "People",
    "Time",
    "Land",
    "Water",
    "Other",
    "Plants",
    "World",
    "Between",
    "Gift",
    "Trees",
    "life",
    "Home",
    "Place",
    "Leaves",
    "Light",
    "Green",
    "Work",
    "Earth",
    "Language",
    "Being",
    "Need",
    "Whole"
]


text_kimmerer = open("kimmerer_sweet.txt").read()
if "?" in text_kimmerer: text_kimmerer = text_kimmerer.replace("?",".")
#if "," in text_kimmerer: text_kimmerer = text_kimmerer.replace(",",".")
#if ";" in text_kimmerer: text_kimmerer = text_kimmerer.replace(";",".")

sentences_kimmerer = text_kimmerer.split(". ")
kimmerer_passages = []
for sentence in sentences_kimmerer:
    word = random.randrange(0, len(kimmerer_keywords))
    if kimmerer_keywords[word] in sentence:
        #print(sentence)
        kimmerer_passages.append(sentence)
        
randChoice = 0
for passage in kimmerer_passages:
    randChoice = random.randrange(0,3)
    if(randChoice == 0):
        print(passage)
    
    
#words_kimmerer = text_kimmerer.split(" ")
#words = []
#words_dict = {}
#for word in words_kimmerer:   
#    if word not in words:
#        words.append(word)
#    elif word not in words_dict.keys():
#        words_dict[word] = 1
#    else:
#        words_dict[word] += 1

#sort_words = sorted(words_dict.items(), key=lambda x: x[1], reverse=True)
#print(sort_words)
    
#sentences_kimmerer = text_kimmerer.split(". ")
#for sentence in sentences_kimmerer:
#    word = random.randrange(0, len(keywords))
#    if keywords[word] in sentence:
#        print(sentence)
# Out:
# They are gifts from our
# sweet Grandmother Earth, which we take without asking
# Its time has come to an end.
# The lichen, in a single body, unites the two great pathways of life:
# the so-called grazing food chain based on the building up of beings,
# and the detrital food chain based on taking them apart
# Trees that were born before Columbus sailed.
# And trees are just the beginning
# The wildlife just snickered
# Mother Nature and Father Time could use
# someone to push a wheelbarrow, and a few intrepid beings have
# volunteered.
# The plant communities that will thrive in this environment are the
# ones that are tolerant of salt and the sodden “soil.” It’s tough to
# imagine a reference ecosystem of native species that could survive.
# But, in presettlement times, there were salt springs around the
# lake, and they supported one of the rarest of native plant
# communities, an inland salt marsh

# %%
castaneda_keywords = [
    "Time",
    "Looked",
    "Power",
    "Felt",
    "Eyes",
    "World",
    "Thought",
    "Place",
    "Other",
    "Down",
    "Body",
    "Moment",
    "Never",
    "Stood",
    "Became",
    "Order",
    "Personal",
    "Myself",
    "Warrior",
    "Wind",
    "Nothing",
    "Everything"
]

text_castaneda = open("castaneda_ixtlan.txt").read()
if "?" in text_castaneda: text_castaneda = text_castaneda.replace("?",".")
#if "," in text_castaneda: text_castaneda = text_castaneda.replace(",",".")
#if ";" in text_castaneda: text_castaneda = text_castaneda.replace(";",".")
#sentences_castaneda = text_castaneda.split(". ")
#for sentence in sentences_castaneda:
#    word = random.randrange(0, len(keywords))
#    if keywords[word] in sentence:
#        print(sentence)

sentences_castaneda = text_castaneda.split(". ")
castaneda_passages = []
for sentence in sentences_castaneda:
    word = random.randrange(0, len(castaneda_keywords))
    if castaneda_keywords[word] in sentence:
        #print(sentence)
        castaneda_passages.append(sentence)
        
randChoice = 0
for passage in castaneda_passages:
    randChoice = random.randrange(0,2)
    if(randChoice == 0):
        print(passage)

#words_castaneda = text_castaneda.split(" ")
#words = []
#words_dict = {}
#for word in words_castaneda:   
#    if word not in words:
#        words.append(word)
#    elif word not in words_dict.keys():
#        words_dict[word] = 1
#    else:
#        words_dict[word] += 1

#sort_words = sorted(words_dict.items(), key=lambda x: x[1], reverse=True)
#print(sort_words)
# Out:
# "Nothing could be more or less
# serious than anything else
# Thus he must always be in a
# state of readiness.
# "You know about the wind, and now you may hunt power in the wind by yourself.
# But there are other things you don't know about which are, like the wind, the center of
# power at certain times and at certain places.
# "Power is a very peculiar affair, " he said
# Power is personal
# I had no thoughts or feelings.
# Everything had been turned off and I was floating freely

# %%
possible_lines = [
    "humans, in an indigenous and oral context", 
    "their own consciousness as simply one form of awareness among many others",
    "Yet we can never suspend the flux of participation itself",
    "Until now we have spoken of perception in primarily visual terms",
    "Our own languages are continually nourished by these other voices",
    "by the roar of waterfalls and the thrumming of crickets",
    "Once fixed on the written surface, mythic events are no longer able to shift",
    "Human language evolved in a thoroughly animistic context",
    "not only as a means of communication between humans",
    "propitiating, praising, and appeasing the expressive powers of the surrounding terrain",
    "Everything is a wild toss of hallucinations of one kind or another about one thing or another",
    "This makes the future less certain and less real than the past",
    "As one of Stanghellini’s patients says movingly",
    "How can this world be real, when it is only seen through my brain",
    "Seen in this way, the future is no more than a fantasy, a fabrication, and a hope",
    "it belongs to the unreal, the counterfactual",
    "Humans often pray and forget what their mouths can do",
    "forget that every ear is listening", 
    "when you direct your longing to the gods, they can take that personally",
    "His words were floating up toward the old ceiling",
    "I felt her immediately and the brothersisters lifted off my mind in a hurried cloud",
    "Love does people like that",
    "These ceremonies too magnify life",
    "Trees that were born before Columbus sailed",
    "And trees are just the beginning",
    "The wildlife just snickered",
    "Power is personal",
    "But there are other things you don't know about which are, like the wind",
    "the center of power at certain times and at certain places",
    "Everything had been turned off and I was floating freely"
]

# %%
stanza = 0
randChoice = 0

for x in range(50):
    x = x%25
    line = random.randrange(0,25)
    start = random.randrange(0,10)
    if(possible_lines[line][(start - 1)] == " "):
        print(possible_lines[line] + ",")
        #[start:]
    
    stanza += 1
    
    randChoice = random.randrange(0,3)
    
    if(randChoice == 0):
        if(possible_lines[x][(start - 1)] == " "):
            print(possible_lines[x][start:] + ",")
    
    if stanza == 3:
        stanza = 0
        print()
# Out:
# humans, in an indigenous and oral context,
# Yet we can never suspend the flux of participation itself,
#
#
#
#
#
# Love does people like that,
#
# I felt her immediately and the brothersisters lifted off my mind in a hurried cloud,
# Yet we can never suspend the flux of participation itself,
#
#
# not only as a means of communication between humans,
# Trees that were born before Columbus sailed,
#
# As one of Stanghellini’s patients says movingly,
# Our own languages are continually nourished by these other voices,
#
# by the roar of waterfalls and the thrumming of crickets,
#
#
#
# Our own languages are continually nourished by these other voices,
